# %% [markdown]
# # Feature Engineering & Label Construction
#
# This notebook transforms raw operational data into:
# - a feature matrix (X)
# - a binary target variable (delivery_failed)
#
# All assumptions are explicitly documented.

# %%
# Notebook 02 – sanity check
import sys
import pandas as pd

print("Python version:", sys.version)
print("Pandas version:", pd.__version__)
